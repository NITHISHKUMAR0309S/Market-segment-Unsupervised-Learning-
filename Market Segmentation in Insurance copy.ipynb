# %% [markdown]
# # Unsupervised Learning

# %% [markdown]
# | Library               | Alias  | Description                                                                 |
# |-----------------------|--------|-----------------------------------------------------------------------------|
# | **pandas**            | `pd`   | Used for **data manipulation and analysis** (loading, cleaning, exploring datasets). |
# | **matplotlib.pyplot** | `plt`  | Used for **creating visualizations** like line plots, bar charts, and histograms. |
# | **seaborn**           | `sns`  | Built on top of Matplotlib; provides a **high-level interface** for attractive and informative statistical graphics. |

# %%
import pandas as pd

import matplotlib.pyplot as plt

import seaborn as sns

# %%
df=pd.read_csv("Datasets/Customer Data.csv")
df
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
df.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
df.tail()
# Out:
#      CUST_ID     BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 8945  C19186   28.493517           1.000000     291.12              0.00
# 8946  C19187   19.183215           1.000000     300.00              0.00
# 8947  C19188   23.398673           0.833333     144.40              0.00
# 8948  C19189   13.457564           0.833333       0.00              0.00
# 8949  C19190  372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 8945                  291.12      0.000000             1.000000
# 8946                  300.00      0.000000             1.000000
# 8947                  144.40      0.000000             0.833333
# 8948                    0.00     36.558778             0.000000
# 8949                    0.00    127.040008             0.666667
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 8945                    0.000000                          0.833333
# ...

# %%
df.columns
# Out:
# Index(['CUST_ID', 'BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES',
#        'ONEOFF_PURCHASES', 'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE',
#        'PURCHASES_FREQUENCY', 'ONEOFF_PURCHASES_FREQUENCY',
#        'PURCHASES_INSTALLMENTS_FREQUENCY', 'CASH_ADVANCE_FREQUENCY',
#        'CASH_ADVANCE_TRX', 'PURCHASES_TRX', 'CREDIT_LIMIT', 'PAYMENTS',
#        'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT', 'TENURE'],
#       dtype='object')

# %%
df.shape
# Out:
# (8950, 18)

# %%
df.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
for col in ['BALANCE','PURCHASES']:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    df[col] = df[col].clip(lower=lower_bound, upper=upper_bound)

# %%
import matplotlib.pyplot as plt
plt.Figure(figsize=(10,12))
sns.boxplot(x=df['BALANCE'])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.Figure(figsize=(10,12))
sns.boxplot(x=df['PURCHASES'])
plt.show()

# %%
# Out:
#            BALANCE  BALANCE_FREQUENCY    PURCHASES  ONEOFF_PURCHASES  \
# count  8950.000000        8950.000000  8950.000000       8950.000000
# mean   1390.508973           0.877271   737.149330        592.437371
# std    1537.538479           0.236904   879.534788       1659.887917
# min       0.000000           0.000000     0.000000          0.000000
# 25%     128.281915           0.888889    39.635000          0.000000
# 50%     873.385231           1.000000   361.280000         38.000000
# 75%    2054.140036           1.000000  1110.130000        577.405000
# max    4942.927215           1.000000  2715.872500      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %%
x=df[['BALANCE','PURCHASES']]
x
# Out:
#           BALANCE  PURCHASES
# 0       40.900749      95.40
# 1     3202.467416       0.00
# 2     2495.148862     773.17
# 3     1666.670542    1499.00
# 4      817.714335      16.00
# ...           ...        ...
# 8945    28.493517     291.12
# 8946    19.183215     300.00
# 8947    23.398673     144.40
# 8948    13.457564       0.00
# 8949   372.708075    1093.25
#
# [8950 rows x 2 columns]

# %%
df[['BALANCE','PURCHASES']].describe()
# Out:
#            BALANCE    PURCHASES
# count  8950.000000  8950.000000
# mean   1390.508973   737.149330
# std    1537.538479   879.534788
# min       0.000000     0.000000
# 25%     128.281915    39.635000
# 50%     873.385231   361.280000
# 75%    2054.140036  1110.130000
# max    4942.927215  2715.872500

# %% [markdown]
# # 📊 KMeans Clustering
#
# **KMeans** is an unsupervised machine learning algorithm used for **clustering** data into groups based on feature similarity.
#
# ---
#
# ### 🔹 How It Works
# 1. Choose the number of clusters **k**.
# 2. Randomly initialize **k centroids**.
# 3. Assign each data point to the **nearest centroid**.
# 4. Recalculate centroids based on current cluster members.
# 5. Repeat steps 3–4 until centroids **stabilize** (no significant changes).
#
# ---
#
# ### 🔹 Example in Python
# ```python
# from sklearn.cluster import KMeans
#
# # Initialize KMeans
# kmeans = KMeans(n_clusters=3, random_state=42)
#
# # Fit model
# kmeans.fit(X)
#
# # Get cluster labels
# labels = kmeans.labels_
#
# # Get centroids
# centroids = kmeans.cluster_centers_

# %%
from sklearn.cluster import KMeans
wcss = []
for i in range(1,11):  
    km=KMeans(n_clusters=i, random_state=0)
    km.fit(x)
    wcss.append(km.inertia_)
plt.plot(range(1,11),wcss,color="olive", marker ="8")
plt.title('Optimal K Value')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
from sklearn.cluster import KMeans
km=KMeans(n_clusters=4,random_state=23)
km.fit(x)
labels=km.labels_
labels
from sklearn.metrics import silhouette_score
sco=silhouette_score(x,labels)
print(sco)
# Out:
# 0.4967063061967621

# %%
km.inertia_
# Out:
# 5279442091.670118

# %%
x=df[['PURCHASES','BALANCE']]
plt.Figure(figsize=(10,15))
plt.scatter(x[labels==0]['PURCHASES'],x[labels==0]['BALANCE'],s=40,c='red',label='cluster 1')
plt.scatter(x[labels==1]['PURCHASES'],x[labels==1]['BALANCE'],s=40,c='cyan',label='cluster 2')
plt.scatter(x[labels==2]['PURCHASES'],x[labels==2]['BALANCE'],s=40,c='orange',label='cluster 3')
plt.scatter(x[labels==3]['PURCHASES'],x[labels==3]['BALANCE'],s=40,c='purple',label='cluster 4')
plt.xlabel('PURCHASES')
plt.ylabel('BALANCE')
plt.legend()
plt.show()

# %% [markdown]
# # 🔹 Hierarchical Clustering

# %% [markdown]
# **Hierarchical Clustering** is an unsupervised learning technique that builds a hierarchy of clusters either **bottom-up (agglomerative)** or **top-down (divisive)**.
#
# ---
#
# ### 🔹 How It Works
# 1. **Agglomerative (bottom-up)**:
#    - Start with each data point as its own cluster.
#    - Iteratively merge the closest clusters until all points belong to one cluster or a stopping criterion is met.
# 2. **Divisive (top-down)**:
#    - Start with all points in one cluster.
#    - Iteratively split clusters until each point is its own cluster or a stopping criterion is met.
# 3. The result is often visualized as a **dendrogram**.
#
# ---
#
# ### 🔹 Example in Python
# ```python
# from scipy.cluster.hierarchy import dendrogram, linkage
# import matplotlib.pyplot as plt
#
# # Generate linkage matrix
# Z = linkage(X, method='ward')
#
# # Plot dendrogram
# plt.figure(figsize=(10, 5))
# dendrogram(Z)
# plt.title("Hierarchical Clustering Dendrogram")
# plt.xlabel("Samples")
# plt.ylabel("Distance")
# plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering
Ac=AgglomerativeClustering()
Ac.fit(x)
# Out:
# AgglomerativeClustering()

# %%
import scipy.cluster.hierarchy as cl 
plt.Figure(figsize=(20,15))
den=cl.dendrogram(cl.linkage(x,method='ward'))
plt.title('Dendogram graph')
plt.xlabel('PURCHASES')
plt.ylabel('BALANCE')
plt.show()

# %%
import scipy.cluster.hierarchy as cl 
plt.Figure(figsize=(20,15))
den=cl.dendrogram(cl.linkage(x,method='single'))
plt.title('Dendogram graph')
plt.xlabel('PURCHASES')
plt.ylabel('BALANCE')
plt.show()

# %%
import scipy.cluster.hierarchy as cl 
plt.Figure(figsize=(20,15))
den=cl.dendrogram(cl.linkage(x,method='complete'))
plt.title('Dendogram graph')
plt.xlabel('PURCHASES')
plt.ylabel('BALANCE')
plt.show()

# %%
import scipy.cluster.hierarchy as cl 
plt.Figure(figsize=(20,15))
den=cl.dendrogram(cl.linkage(x,method='average'))
plt.title('Dendogram graph')
plt.xlabel('PURCHASES')
plt.ylabel('BALANCE')
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering
md=AgglomerativeClustering(n_clusters=8,linkage='ward')
y_mean=md.fit_predict(x)
y_mean
# Out:
# array([3, 0, 0, ..., 3, 3, 4], shape=(8950,))

# %%
x=df.iloc[:,[1,3]].values
plt.scatter(x[y_mean==0,0], x[y_mean==0,1],s=30,c='yellow',label='cluster 1')
plt.scatter(x[y_mean==1,0], x[y_mean==1,1],s=30,c='red',label='cluster 2')
plt.scatter(x[y_mean==2,0], x[y_mean==2,1],s=30,c='green',label='cluster 3')
plt.scatter(x[y_mean==3,0], x[y_mean==3,1],s=30,c='violet',label='cluster 4')
plt.scatter(x[y_mean==4,0], x[y_mean==4,1],s=30,c='black',label='cluster 5')
plt.scatter(x[y_mean==5,0], x[y_mean==5,1],s=30,c='blue',label='cluster 6')
plt.scatter(x[y_mean==6,0], x[y_mean==6,1],s=30,c='purple',label='cluster 7')
plt.scatter(x[y_mean==7,0], x[y_mean==7,1],s=30,c='gray',label='cluster 8')
plt.legend()
plt.xlabel('PURCHASES')
plt.ylabel('BALANCE')
plt.show()

# %% [markdown]
# # 🔹 DBSCAN (Density-Based Spatial Clustering of Applications with Noise)
#
# **DBSCAN** is an unsupervised clustering algorithm that groups together points that are **closely packed** while marking points in low-density regions as **outliers/noise**.
#
# ---
#
# ### 🔹 How It Works
# 1. Two main parameters:
#    - `eps` → maximum distance between two points to be considered neighbors.
#    - `min_samples` → minimum number of points required to form a dense region.
# 2. Points are classified as:
#    - **Core Points** → have at least `min_samples` neighbors within `eps`.
#    - **Border Points** → neighbors of core points but not enough to be core themselves.
#    - **Noise Points** → do not belong to any cluster.
# 3. Clusters are formed by connecting core points and their neighbors.
#
# ---
#
# ### 🔹 Example in Python
# ```python
# from sklearn.cluster import DBSCAN
#
# # Initialize DBSCAN
# dbscan = DBSCAN(eps=0.5, min_samples=5)
#
# # Fit model and get labels
# labels = dbscan.fit_predict(X)

# %%
from sklearn.cluster import DBSCAN
dbs=DBSCAN(eps=8,min_samples=3 )   
dbs.fit(x)
# Out:
# DBSCAN(eps=8, min_samples=3)

# %%
from sklearn.metrics import silhouette_score
s=silhouette_score(x,labels,sample_size=10)
print(s)
# Out:
# 0.15327317542906696

# %%
x = df.iloc[:, [1,3]].values
plt.scatter(x[labels==0, 0], x[labels==0, 1], s=50, c='purple', label ='Cluster 1')
plt.scatter(x[labels==1, 0], x[labels==1, 1], s=50, c='orange', label ='Cluster 2')
plt.scatter(x[labels==2, 0], x[labels==2, 1], s=50, c='red', label ='Cluster 3')
plt.scatter(x[labels==3, 0], x[labels==3, 1], s=50, c='green', label ='Cluster 4')
plt.xlabel('PURCHASES')
plt.ylabel('BALANCE')
plt.legend()
plt.show()
